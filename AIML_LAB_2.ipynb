# %% [markdown]
# <a href="https://colab.research.google.com/github/Saivamshi-2628/2303A52238-Aiml/blob/main/AIML_LAB_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statistics as stat
from scipy.stats import skew
from scipy.stats import  kurtosis
from scipy.stats import iqr
data=pd.read_csv('/content/drive/MyDrive/Document from Nani',usecols=(['Age']))

#data.tail(-1)
#print(data)
p=data.head(20)
print(data)
print(data.head(20))
#plt.hist(data,100)
print("The mean of the data=",np.mean(data))
print("The median of the data=",np.median(data))
print("The mode of the data=",stat.mode(data))
print("The sd of the data=",np.std(data))
print("The skew of the data=",skew(data,axis=0,bias=True))
print("The kurtosis of the data=",kurtosis(data,axis=0,bias=True))
print("The IQR of the data=",iqr(data))
data=data.Age
plt.figure(figsize=(10,10))
plt.hist(data, bins=30, color='yellow', edgecolor='black')
plt.xlabel('no.of people')
plt.ylabel('age')
plt.title('histogram graph')
plt.show(' ')
# Out:
#      Age
# 0     70
# 1     55
# 2     42
# 3     84
# 4     86
# ..   ...
# 995   42
# 996   80
# 997   64
# 998   84
# 999   61
#
# [1000 rows x 1 columns]
#     Age
# 0    70
# 1    55
# 2    42
# 3    84
# 4    86
# 5    66
# 6    33
# 7    84
# 8    73
# 9    63
# 10   88
# 11   69
# 12   78
# 13   89
# 14   71
# 15   30
# 16   77
# 17   86
# 18   76
# 19   74
# The mean of the data= 60.338
# The median of the data= 60.5
# The mode of the data= Age
# The sd of the data= Age    17.308835
# dtype: float64
# The skew of the data= [-0.03564232]
# The kurtosis of the data= [-1.24859277]
# The IQR of the data= 31.0
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3643: FutureWarning: The behavior of DataFrame.std with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return std(axis=axis, dtype=dtype, out=out, ddof=ddof, **kwargs)

# %% [markdown]
# # New Section
